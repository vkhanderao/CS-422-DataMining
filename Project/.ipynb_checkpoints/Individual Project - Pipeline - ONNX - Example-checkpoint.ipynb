# %%
# !pip install skl2onnx
# !pip install onnxruntime
# Out:
# Collecting skl2onnx
#   Downloading https://files.pythonhosted.org/packages/2e/2e/efe7874c6b92ce4dd262b58a2860e9bf50097c68588114a542b29affca46/skl2onnx-1.8.0-py2.py3-none-any.whl (230kB)
# Collecting onnxconverter-common<1.9,>=1.6.1 (from skl2onnx)
#   Downloading https://files.pythonhosted.org/packages/42/f5/82c29029a643dd4de8e0374fe2d5831f50ca58623dd1ee41e0b8df8a7d71/onnxconverter_common-1.8.1-py2.py3-none-any.whl (77kB)
# Collecting onnx>=1.2.1 (from skl2onnx)
#   Downloading https://files.pythonhosted.org/packages/ec/5c/18c9c358eb4cd8c41b18338f86ed1d43a3a61b970784cd8525597bfe5c4a/onnx-1.8.1-cp37-cp37m-win_amd64.whl (6.9MB)
# Requirement already satisfied: numpy>=1.15 in c:\users\venka\anaconda3\lib\site-packages (from skl2onnx) (1.16.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\venka\anaconda3\lib\site-packages (from skl2onnx) (1.3.1)
# Requirement already satisfied: scikit-learn>=0.19 in c:\users\venka\anaconda3\lib\site-packages (from skl2onnx) (0.21.3)
# Requirement already satisfied: protobuf in c:\users\venka\anaconda3\lib\site-packages (from skl2onnx) (3.13.0)
# Requirement already satisfied: six in c:\users\venka\anaconda3\lib\site-packages (from skl2onnx) (1.12.0)
# Collecting typing-extensions>=3.6.2.1 (from onnx>=1.2.1->skl2onnx)
#   Using cached https://files.pythonhosted.org/packages/60/7a/e881b5abb54db0e6e671ab088d079c57ce54e8a01a3ca443f561ccadb37e/typing_extensions-3.7.4.3-py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in c:\users\venka\anaconda3\lib\site-packages (from scikit-learn>=0.19->skl2onnx) (0.13.2)
# Requirement already satisfied: setuptools in c:\users\venka\anaconda3\lib\site-packages (from protobuf->skl2onnx) (41.4.0)
# Installing collected packages: typing-extensions, onnx, onnxconverter-common, skl2onnx
# Successfully installed onnx-1.8.1 onnxconverter-common-1.8.1 skl2onnx-1.8.0 typing-extensions-3.7.4.3
# ERROR: onnx 1.8.1 has requirement numpy>=1.16.6, but you'll have numpy 1.16.5 which is incompatible.
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/88/ac/ae86d5fa7509fd72ed4663386d9b650972264a87b36de7a915826a9c0957/onnxruntime-1.7.0-cp37-cp37m-win_amd64.whl (4.4MB)
# Requirement already satisfied: protobuf in c:\users\venka\anaconda3\lib\site-packages (from onnxruntime) (3.13.0)
# Collecting numpy>=1.16.6 (from onnxruntime)
#   Downloading https://files.pythonhosted.org/packages/7d/3f/152a89cfdacbf747066268a93aae7d1911efc89abcbcf851f16d7881b85e/numpy-1.20.2-cp37-cp37m-win_amd64.whl (13.6MB)
# Requirement already satisfied: six>=1.9 in c:\users\venka\anaconda3\lib\site-packages (from protobuf->onnxruntime) (1.12.0)
# Requirement already satisfied: setuptools in c:\users\venka\anaconda3\lib\site-packages (from protobuf->onnxruntime) (41.4.0)
# Installing collected packages: numpy, onnxruntime
#   Found existing installation: numpy 1.16.5
#     Uninstalling numpy-1.16.5:
#       Successfully uninstalled numpy-1.16.5
# ERROR: fastai 1.0.60 requires fastprogress>=0.2.1, which is not installed.
# ERROR: fastai 1.0.60 requires nvidia-ml-py3, which is not installed.
# ERROR: fastai 1.0.60 requires spacy>=2.0.18, which is not installed.
# ERROR: fastai 1.0.60 requires torch>=1.0.0, which is not installed.
# ERROR: fastai 1.0.60 requires torchvision, which is not installed.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\venka\\anaconda3\\lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import os

import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.datasets import load_iris

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.tree import DecisionTreeClassifier

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline


from skl2onnx.common.data_types import FloatTensorType
from skl2onnx import convert_sklearn

import onnxruntime as rt

from onnx.tools.net_drawer import GetPydotGraph, GetOpNodeProducer

import graphviz

# %%
iris_data = load_iris()

X = pd.DataFrame(data=iris_data.data,
                 columns=['_'.join(feature_name.split()[:2]) for feature_name in iris_data.feature_names])
y = pd.DataFrame(data=iris_data.target,
                 columns=['species'])

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.1,
                                                    stratify=y,
                                                    random_state=42)

# %%
iris_train = pd.concat([X_train,
                        y_train],
                       axis=1)
iris_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 29            4.7          3.2           1.6          0.2        0
# 145           6.7          3.0           5.2          2.3        2
# 8             4.4          2.9           1.4          0.2        0
# 148           6.2          3.4           5.4          2.3        2
# 25            5.0          3.0           1.6          0.2        0

# %%
iris_test = pd.concat([X_test,
                       y_test],
                      axis=1)
iris_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 58            6.6          2.9           4.6          1.3        1
# 134           6.1          2.6           5.6          1.4        2
# 147           6.5          3.0           5.2          2.0        2
# 69            5.6          2.5           3.9          1.1        1
# 107           7.3          2.9           6.3          1.8        2

# %%
sepal_features = [0,1]
petal_features = [2,3]

sepal_transformer = Pipeline(steps=[
    ('imputer',
     SimpleImputer(strategy='mean')),
    ('scaler',
     StandardScaler())
])

petal_transformer = Pipeline(steps=[
    ('imputer',
     SimpleImputer(strategy='median')),
    ('scaler',
     StandardScaler())
])

preprocessor = ColumnTransformer(transformers=[
    ('sepal',
     sepal_transformer,
     sepal_features),
    ('petal',
     petal_transformer,
     petal_features)
])

classifier = DecisionTreeClassifier()

# %%
pipeline = Pipeline([
    ('precprocessor',
     preprocessor),
    ('classifier',
     classifier)
])

pipeline.fit(iris_train.drop('species',axis=1),
             iris_train['species']);

# %%
print(classification_report(pipeline.predict(X_train),
                            y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        45
#            1       1.00      1.00      1.00        45
#            2       1.00      1.00      1.00        45
#
#     accuracy                           1.00       135
#    macro avg       1.00      1.00      1.00       135
# weighted avg       1.00      1.00      1.00       135

# %%
pipeline.predict(X_test)
# Out:
# array([1, 1, 2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 1, 2, 0])

# %%
y_test.values.ravel()
# Out:
# array([1, 2, 2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 1, 1, 0])

# %%
print(classification_report(pipeline.predict(X_test),
                            y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.80      0.80      0.80         5
#            2       0.80      0.80      0.80         5
#
#     accuracy                           0.87        15
#    macro avg       0.87      0.87      0.87        15
# weighted avg       0.87      0.87      0.87        15

# %%
input_types = dict([(x, FloatTensorType([None, 1])) for x in X_train.columns.values])

try:
    model_onnx = convert_sklearn(pipeline,
                                 'pipeline_iris_onnx',
                                initial_types=list(input_types.items()))
except Exception as e:
    print(e)

with open("iris_pipeline.onnx", "wb") as f:
    f.write(model_onnx.SerializeToString())

# %%
inputs_onnx = {k: np.array(v).astype(np.float32)[:, np.newaxis] for k, v in X_test.to_dict(orient='list').items()}

session_onnx = rt.InferenceSession("iris_pipeline.onnx")
predict_onnx = session_onnx.run(None, inputs_onnx)
print("predict", predict_onnx[0])
# Out:
# predict [1 1 2 1 2 0 0 0 2 1 0 2 1 2 0]

# %%
pydot_graph = GetPydotGraph(model_onnx.graph,
                            name=model_onnx.graph.name,
                            rankdir="TB",
                            node_producer=GetOpNodeProducer("docstring",
                                                            color="yellow",
                                                            fillcolor="yellow",
                                                            style="filled"))

graphviz.Source(pydot_graph)
